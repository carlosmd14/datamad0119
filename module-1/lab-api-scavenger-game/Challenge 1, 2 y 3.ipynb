# %%
# NOTA: En el Challenge 3 la intenció era obtener las palabras desde los "Content", para luego con un simple bucle
# decodificarlas, pero entre las limitaciones de los API rates y que la iteración no completaba, se me ha hecho 
# imposible y he preferido enfocarme en terminar el proyecto.


from dotenv import load_dotenv
import os
import requests

# KEY
load_dotenv(dotenv_path='.env')
SECRET_KEY = os.getenv("TOKEN")

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/datamad0119/forks')
results = response.json()
results
# Out:
# {'message': "API rate limit exceeded for 83.56.59.250. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)",
#  'documentation_url': 'https://developer.github.com/v3/#rate-limiting'}

# %%
languages = []

for result in results:
    if result['language'] not in languages:
        languages.append(result['language'])

languages
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-c4edc64fd5e8> in <module>
#       2
#       3 for result in results:
# ----> 4     if result['language'] not in languages:
#       5         languages.append(result['language'])
#       6
#
# TypeError: string indices must be integers

# %%
response2 = requests.get('https://api.github.com/repos/ironhack-datalabs/datamad0119/stats/participation')
results2 = response2.json()

# %%
results2['all'][-1]

# %%
response3 = requests.get('https://api.github.com/repos/ironhack-datalabs/datamad0119/stats/commit_activity')
results3 = response3.json()
results3[-2]['total']

# %%
response3 = requests.get('https://api.github.com/repos/ironhack-datalabs/datamad0119/stats/commit_activity')
results3 = response3.json()
results3[-2]['total']
# Out:
# 4

# %%
response5 = requests.get('https://api.github.com/search/code?q=filename:.0001.scavengerhunt+repo:ironhack-datalabs/scavenger')

# %%
# results5 = response5.json()
# results5
allresults = []
res = []
for x in range(1,25):
    allresults.append(requests.get('https://api.github.com/search/code?q=filename:.00{:02}.scavengerhunt+repo:ironhack-datalabs/scavenger'.format(x)).json())
allresults
# Out:
# [{'total_count': 1,
#   'incomplete_results': False,
#   'items': [{'name': '.0001.scavengerhunt',
#     'path': '98750/.0001.scavengerhunt',
#     'sha': '2add7632f1323136324efbf38ec66db1838b6173',
#     'url': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#     'git_url': 'https://api.github.com/repositories/162375181/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#     'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt',
#     'repository': {'id': 162375181,
#      'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#      'name': 'scavenger',
#      'full_name': 'ironhack-datalabs/scavenger',
#      'private': False,
#      'owner': {'login': 'ironhack-datalabs',
#       'id': 44225188,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
# ...

# %%
for x in allresults:   
    i = 0
    for y in x['items']:  
        content = requests.get(y['url']).json()['content']
        res.append(content)
        if i in [9, 18, 26]: 
            time.sleep(60)
        i += 1
res
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-44a3ddbde127> in <module>
#       2     i = 0
#       3     for y in x['items']:
# ----> 4         content = requests.get(y['url']).json()['content']
#       5         res.append(content)
#       6         if i in [9, 18, 26]:
#
# KeyError: 'content'
